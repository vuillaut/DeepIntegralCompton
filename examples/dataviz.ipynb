# %% [markdown]
# # Data Viz

# %%
# %load_ext autoreload
# %autoreload  2

# %%
from deepcompton.utils import load_data, get_test_data_path
import deepcompton.vizualisation as viz

# %%
data, theta, phi = load_data(get_test_data_path())
theta, phi
# Out:
# (42, 104)

# %%
data.head()
# Out:
#      e1     e2   yy1   zz1   yy2   zz2         y1         z1         y2  \
# 0  88.0  351.0  37.0  46.0  27.0  14.0  16.796875  20.937500  24.375000
# 1  84.0  204.0  29.0  72.0   7.0  42.0  13.109375  32.875000   5.980469
# 2  83.0  388.0  43.0  65.0  30.0  35.0  19.546875  29.671875  27.140625
# 3  57.0  281.0  19.0  58.0   8.0  41.0   8.507812  26.453125   6.898438
# 4  16.0  273.0  82.0  46.0  48.0  29.0  37.500000  20.937500  43.687500
#
#           z2
# 0  12.421875
# 1  38.187500
# 2  31.734375
# 3  37.250000
# 4  26.218750

# %%
data.hist(figsize=(15,10));

# %%
data.describe()
# Out:
#            e1      e2         yy1         zz1        yy2         zz2  \
# count  2543.0  2543.0  2543.00000  2543.00000  2543.0000  2543.00000
# mean      inf     inf         inf         inf        inf         inf
# std       inf     inf    35.78125    35.28125    17.6875    17.84375
# min      12.0   170.0     1.00000     1.00000     1.0000     1.00000
# 25%      42.0   232.0    29.00000    39.00000    19.0000    23.00000
# 50%      92.0   295.0    55.00000    69.00000    34.0000    38.00000
# 75%     182.0   390.0    90.00000    97.00000    49.0000    52.00000
# max     832.0   959.0   130.00000   134.00000    65.0000    67.00000
#
#                 y1           z1           y2           z2
# count  2543.000000  2543.000000  2543.000000  2543.000000
# mean           inf          inf          inf          inf
# std      16.468750    16.218750    16.265625    16.406250
# min       0.229980     0.229980     0.459961     0.459961
# ...

# %%
data['e0'] = data['e1'] + data['e2']

# %%
data.e0.hist()
# Out:
# <AxesSubplot:>

# %%
viz.hist2d_plans(data, bins=20)
# Out:
# array([<AxesSubplot:title={'center':'ISGRI'}, xlabel='y / cm', ylabel='z / cm'>,
#        <AxesSubplot:title={'center':'PICSIT'}, xlabel='y / cm', ylabel='z / cm'>],
#       dtype=object)

# %%
viz.scatter_plans(data, s=5);

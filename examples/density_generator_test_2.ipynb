# %%
import deepcompton
import os
import numpy as np
import matplotlib.pyplot as plt
print(os.getcwd())

data_dir = "../save_Compton"
if not os.path.exists(data_dir):
    print("Could not find data directory {}".format(data_dir))
# Out:
# /home/aschulz/Documents/python/astroinfo2021/compton-hackathon/DeepIntegralCompton/examples

# %%
# instrument caracteristics
z_isgri = 0.
z_picsit = -8.68

# %%
# first we need to create the dataset used for training and testing
from deepcompton.cones import make_cone_density
def make_dataset(datadir, max_n = 1000):
    y,x=[],[]
    for f in os.listdir(datadir):
        _,theta,_,phi=f.replace(".npy","").split("_")
        data = make_cone_density(theta, phi, z_isgri, z_picsit, datadir=datadir, progress=False)
        if data is not None:
            y.append([float(theta),float(phi)])
            x.append(data.reshape(180,45,1))
        if len(y)==max_n:
            break
        print(len(y))
    return np.array(x),np.array(y)
# pickled data
pkl_filename = "../cone_density_data_full.pkl"
if os.path.exists(pkl_filename):
    import pickle as pkl
    fdata=pkl.load(open(pkl_filename,"rb"))
    x=[e[1] for e in fdata]
    y=[e[0] for e in fdata]
    def clean_pkl_data(x,y):
        a,b=[],[]
        for i in range(len(x)):
            if x[i] is not None:
                a.append(x[i].reshape(180,45,1))
                b.append(np.array([float(y[i][0]),float(y[i][1])]))
        return np.array(a),np.array(b)
    x,y = clean_pkl_data(x,y)
    
else:
    x,y = make_dataset(data_dir)
    pkl.dump((x,y),open(pkl_filename,"wb"))
print(x.shape, y.shape)
# Out:
# (3715, 180, 45, 1) (3715, 2)

# %%
# plot the distribution of the data
plt.figure()
plt.hist(x[0].flatten(),bins=100)
plt.show()

# %%
# normalize the data
from sklearn.preprocessing import scale
flat_x=[]
for i in range(x.shape[0]):
    flat_x.append(x[i].flatten())
flat_x=np.array(flat_x)


flat_x = scale(flat_x)

new_x = [flat_x[i].reshape(180,45,1) for i in range(flat_x.shape[0])]
new_x = np.array(new_x)
plt.figure()
plt.hist(new_x[0].flatten(),bins=100)
plt.show()

# %%
#from deepcompton.vizualisation import plot_backprojected
#plot_backprojected(y[0,0],y[0,1], x[0])

# %%
# creating the train and test data
from sklearn.model_selection import train_test_split
import tensorflow as tf
x_train,x_test, y_train,y_test = train_test_split(new_x, y, shuffle=True)

y_train,y_test = np.array(y_train), np.array(y_test)
x_train,x_test = np.array(x_train), np.array(x_test)
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)

# convert to tensorflow tensors
y_train = tf.convert_to_tensor(y_train)
x_train = tf.convert_to_tensor(x_train)
#y_test= tf.convert_to_tensor(y_test)
#x_test= tf.convert_to_tensor(x_test)
print("Train data : {} {}".format(x_train.shape, y_train.shape))
print("Test data  : {} {}".format(x_test.shape, y_test.shape))
# Out:
# (2786, 180, 45, 1) (2786, 2) (929, 180, 45, 1) (929, 2)
# Train data : (2786, 180, 45, 1) (2786, 2)
# Test data  : (929, 180, 45, 1) (929, 2)

# %%
# definition of a first convolutional model
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, Dense, Flatten
def get_model():
    model = tf.keras.Sequential()
    model.add(Conv2D(32,3,input_shape=(180,45,1), activation="elu"))
    model.add(BatchNormalization())
    #model.add(Conv2D(64,3, activation="elu"))
    #model.add(BatchNormalization())
    model.add(Flatten())
    model.add(Dense(512,activation="elu"))
    model.add(BatchNormalization())
    #model.add(Dense(128,activation="relu"))
    #model.add(BatchNormalization())
    model.add(Dense(2, activation="elu"))
    return model

# %%
from deepcompton.utils import angular_separation
def angular_loss(y_true, y_pred):
    # convert to rad
    _deg2rad = np.pi / 180.
    _lat1,_lon1=y_true[-1][0]*_deg2rad,y_true[-1][1]*_deg2rad
    _lat2,_lon2=y_pred[-1][0]*_deg2rad,y_pred[-1][1]*_deg2rad
    return -1. * (tf.math.sin(_lat1)*tf.math.sin(_lat2)*
                  tf.math.cos(_lon1-_lon2)+
                  tf.math.cos(_lat2)*tf.math.cos(_lat1))

# %%
# create the model
model = get_model()

# %%
epochs = 100
batch_size = 12

callbacks = [
    #keras.callbacks.ModelCheckpoint("save_at_{epoch}.h5"),
    tf.keras.callbacks.TensorBoard('./logs/density_cnn_1_aloss_1layer_1e-2'),
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10),
]



model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-2),
    loss=angular_loss,
    metrics=[angular_loss,"mean_squared_error"],
    #loss=angular_loss,
    #metrics=[angular_loss],
)

# %%
model.fit(
    x_train, y_train, 
    #steps_per_epoch=epochs,
    batch_size=batch_size, 
    epochs=epochs, 
    callbacks=callbacks, 
    validation_split = 0.2,
)
# Out:
# Epoch 1/100
# 186/186 [==============================] - 101s 542ms/step - loss: -0.8034 - angular_loss: -0.8037 - mean_squared_error: 21373.9961 - val_loss: -0.7819 - val_angular_loss: -0.7766 - val_mean_squared_error: 20446.6270
# Epoch 2/100
# 186/186 [==============================] - 118s 633ms/step - loss: -0.7937 - angular_loss: -0.7930 - mean_squared_error: 20746.0879 - val_loss: -0.8240 - val_angular_loss: -0.8232 - val_mean_squared_error: 18582.3594
# Epoch 3/100
# 186/186 [==============================] - 118s 634ms/step - loss: -0.8400 - angular_loss: -0.8402 - mean_squared_error: 19642.3652 - val_loss: -0.8350 - val_angular_loss: -0.8236 - val_mean_squared_error: 18412.2676
# Epoch 4/100
# 186/186 [==============================] - 122s 655ms/step - loss: -0.8136 - angular_loss: -0.8138 - mean_squared_error: 18299.6738 - val_loss: -0.8247 - val_angular_loss: -0.8249 - val_mean_squared_error: 16466.8398
# Epoch 5/100
# 186/186 [==============================] - 121s 652ms/step - loss: -0.8531 - angular_loss: -0.8534 - mean_squared_error: 16398.6699 - val_loss: -0.8353 - val_angular_loss: -0.8362 - val_mean_squared_error: 15013.6475
# Epoch 6/100
# 186/186 [==============================] - 123s 660ms/step - loss: -0.8328 - angular_loss: -0.8328 - mean_squared_error: 15937.8945 - val_loss: -0.8554 - val_angular_loss: -0.8547 - val_mean_squared_error: 15317.4268
# Epoch 7/100
# 186/186 [==============================] - 127s 682ms/step - loss: -0.8704 - angular_loss: -0.8704 - mean_squared_error: 15521.2744 - val_loss: -0.8704 - val_angular_loss: -0.8715 - val_mean_squared_error: 14606.6514
# Epoch 8/100
# 186/186 [==============================] - 145s 779ms/step - loss: -0.8825 - angular_loss: -0.8826 - mean_squared_error: 15145.2568 - val_loss: -0.8987 - val_angular_loss: -0.8987 - val_mean_squared_error: 13862.6113
# Epoch 9/100
# 186/186 [==============================] - 138s 738ms/step - loss: -0.8960 - angular_loss: -0.8961 - mean_squared_error: 14411.6064 - val_loss: -0.8892 - val_angular_loss: -0.8892 - val_mean_squared_error: 12980.7744
# Epoch 10/100
# 186/186 [==============================] - 119s 637ms/step - loss: -0.8871 - angular_loss: -0.8871 - mean_squared_error: 12769.5879 - val_loss: -0.9033 - val_angular_loss: -0.9036 - val_mean_squared_error: 12311.2969
# Epoch 11/100
# 186/186 [==============================] - 141s 759ms/step - loss: -0.9256 - angular_loss: -0.9257 - mean_squared_error: 11945.2783 - val_loss: -0.8741 - val_angular_loss: -0.8751 - val_mean_squared_error: 10273.5635
# Epoch 12/100
# 186/186 [==============================] - 210s 1s/step - loss: -0.8806 - angular_loss: -0.8807 - mean_squared_error: 10144.6084 - val_loss: -0.9081 - val_angular_loss: -0.9081 - val_mean_squared_error: 6712.9932
# Epoch 13/100
# 186/186 [==============================] - 244s 1s/step - loss: -0.9111 - angular_loss: -0.9112 - mean_squared_error: 9962.9473 - val_loss: -0.8814 - val_angular_loss: -0.8827 - val_mean_squared_error: 10872.9316
# Epoch 14/100
# 186/186 [==============================] - 134s 717ms/step - loss: -0.9296 - angular_loss: -0.9296 - mean_squared_error: 10192.1943 - val_loss: -0.8921 - val_angular_loss: -0.8930 - val_mean_squared_error: 9998.7148
# Epoch 15/100
# 186/186 [==============================] - 120s 646ms/step - loss: -0.9135 - angular_loss: -0.9134 - mean_squared_error: 10239.6514 - val_loss: -0.9204 - val_angular_loss: -0.9206 - val_mean_squared_error: 8854.2832
# Epoch 16/100
# 186/186 [==============================] - 133s 715ms/step - loss: -0.9327 - angular_loss: -0.9329 - mean_squared_error: 10206.9014 - val_loss: -0.9258 - val_angular_loss: -0.9261 - val_mean_squared_error: 9570.4121
# Epoch 17/100
# 186/186 [==============================] - 172s 924ms/step - loss: -0.9332 - angular_loss: -0.9333 - mean_squared_error: 10556.4014 - val_loss: -0.9096 - val_angular_loss: -0.9093 - val_mean_squared_error: 9647.2578
# Epoch 18/100
# 186/186 [==============================] - 197s 1s/step - loss: -0.8924 - angular_loss: -0.8925 - mean_squared_error: 10962.5459 - val_loss: -0.9220 - val_angular_loss: -0.9222 - val_mean_squared_error: 9849.5537
# Epoch 19/100
# 186/186 [==============================] - 250s 1s/step - loss: -0.9269 - angular_loss: -0.9270 - mean_squared_error: 10457.3877 - val_loss: -0.9426 - val_angular_loss: -0.9429 - val_mean_squared_error: 8578.1133
# Epoch 20/100
# 186/186 [==============================] - 205s 1s/step - loss: -0.9230 - angular_loss: -0.9231 - mean_squared_error: 9399.3008 - val_loss: -0.9112 - val_angular_loss: -0.9118 - val_mean_squared_error: 7909.7036
# Epoch 21/100
# 186/186 [==============================] - 245s 1s/step - loss: -0.9170 - angular_loss: -0.9170 - mean_squared_error: 9634.1475 - val_loss: -0.9311 - val_angular_loss: -0.9315 - val_mean_squared_error: 8799.3086
# Epoch 22/100
# 186/186 [==============================] - 205s 1s/step - loss: -0.9286 - angular_loss: -0.9285 - mean_squared_error: 10021.0371 - val_loss: -0.9322 - val_angular_loss: -0.9329 - val_mean_squared_error: 8873.6611
# Epoch 23/100
# 186/186 [==============================] - 208s 1s/step - loss: -0.9216 - angular_loss: -0.9204 - mean_squared_error: 9397.8164 - val_loss: -0.9287 - val_angular_loss: -0.9294 - val_mean_squared_error: 7600.9219
# Epoch 24/100
# 186/186 [==============================] - 215s 1s/step - loss: -0.9143 - angular_loss: -0.9145 - mean_squared_error: 9290.1299 - val_loss: -0.9480 - val_angular_loss: -0.9482 - val_mean_squared_error: 7653.8604
# Epoch 25/100
# 186/186 [==============================] - 211s 1s/step - loss: -0.9317 - angular_loss: -0.9318 - mean_squared_error: 9091.8730 - val_loss: -0.9535 - val_angular_loss: -0.9537 - val_mean_squared_error: 8023.1040
# Epoch 26/100
# 186/186 [==============================] - 209s 1s/step - loss: -0.9188 - angular_loss: -0.9189 - mean_squared_error: 9349.7627 - val_loss: -0.9472 - val_angular_loss: -0.9477 - val_mean_squared_error: 7322.1675
# Epoch 27/100
# 186/186 [==============================] - 211s 1s/step - loss: -0.9018 - angular_loss: -0.9019 - mean_squared_error: 8806.2119 - val_loss: -0.8999 - val_angular_loss: -0.9005 - val_mean_squared_error: 8810.6475
# Epoch 28/100
# 186/186 [==============================] - 207s 1s/step - loss: -0.9336 - angular_loss: -0.9332 - mean_squared_error: 9481.8535 - val_loss: -0.9202 - val_angular_loss: -0.9200 - val_mean_squared_error: 8650.6816
# Epoch 29/100
# 186/186 [==============================] - 204s 1s/step - loss: -0.9364 - angular_loss: -0.9364 - mean_squared_error: 9167.9863 - val_loss: -0.9350 - val_angular_loss: -0.9356 - val_mean_squared_error: 6596.5347
# Epoch 30/100
# 186/186 [==============================] - 140s 753ms/step - loss: -0.9124 - angular_loss: -0.9117 - mean_squared_error: 8871.9043 - val_loss: -0.9311 - val_angular_loss: -0.9316 - val_mean_squared_error: 7126.5176
# Epoch 31/100
# 186/186 [==============================] - 291s 2s/step - loss: -0.9091 - angular_loss: -0.9091 - mean_squared_error: 9611.4717 - val_loss: -0.8811 - val_angular_loss: -0.8822 - val_mean_squared_error: 9091.0674
# Epoch 32/100
# 186/186 [==============================] - 107s 575ms/step - loss: -0.9300 - angular_loss: -0.9298 - mean_squared_error: 9897.7148 - val_loss: -0.9309 - val_angular_loss: -0.9311 - val_mean_squared_error: 8066.6738
# Epoch 33/100
# 186/186 [==============================] - 102s 549ms/step - loss: -0.9350 - angular_loss: -0.9350 - mean_squared_error: 9328.4502 - val_loss: -0.9578 - val_angular_loss: -0.9580 - val_mean_squared_error: 7560.4517
# Epoch 34/100
# 186/186 [==============================] - 104s 561ms/step - loss: -0.9315 - angular_loss: -0.9317 - mean_squared_error: 9003.8828 - val_loss: -0.9605 - val_angular_loss: -0.9607 - val_mean_squared_error: 7656.1479
# Epoch 35/100
# 186/186 [==============================] - 103s 553ms/step - loss: -0.9219 - angular_loss: -0.9220 - mean_squared_error: 8416.4072 - val_loss: -0.9430 - val_angular_loss: -0.9435 - val_mean_squared_error: 7622.7886
# Epoch 36/100
# 186/186 [==============================] - 105s 564ms/step - loss: -0.9218 - angular_loss: -0.9219 - mean_squared_error: 8871.0371 - val_loss: -0.9509 - val_angular_loss: -0.9512 - val_mean_squared_error: 8019.2466
# Epoch 37/100
# 186/186 [==============================] - 104s 561ms/step - loss: -0.9198 - angular_loss: -0.9198 - mean_squared_error: 8928.1719 - val_loss: -0.9671 - val_angular_loss: -0.9670 - val_mean_squared_error: 4705.1445
# Epoch 38/100
# 186/186 [==============================] - 104s 558ms/step - loss: -0.9295 - angular_loss: -0.9295 - mean_squared_error: 8592.4971 - val_loss: -0.9338 - val_angular_loss: -0.9345 - val_mean_squared_error: 6693.7295
# Epoch 39/100
# 186/186 [==============================] - 115s 617ms/step - loss: -0.9297 - angular_loss: -0.9296 - mean_squared_error: 8683.0039 - val_loss: -0.9542 - val_angular_loss: -0.9546 - val_mean_squared_error: 6646.6362
# Epoch 40/100
# 186/186 [==============================] - 150s 806ms/step - loss: -0.9288 - angular_loss: -0.9287 - mean_squared_error: 8472.7764 - val_loss: -0.9555 - val_angular_loss: -0.9558 - val_mean_squared_error: 7044.9644
# Epoch 41/100
# 186/186 [==============================] - 141s 757ms/step - loss: -0.9271 - angular_loss: -0.9272 - mean_squared_error: 8111.7739 - val_loss: -0.9363 - val_angular_loss: -0.9369 - val_mean_squared_error: 6357.2109
# Epoch 42/100
# 186/186 [==============================] - 181s 973ms/step - loss: -0.9190 - angular_loss: -0.9191 - mean_squared_error: 8458.1504 - val_loss: -0.9365 - val_angular_loss: -0.9370 - val_mean_squared_error: 7914.0610
# Epoch 43/100
# 186/186 [==============================] - 142s 761ms/step - loss: -0.9339 - angular_loss: -0.9340 - mean_squared_error: 9238.2578 - val_loss: -0.9493 - val_angular_loss: -0.9496 - val_mean_squared_error: 8288.8965
# Epoch 44/100
# 186/186 [==============================] - 180s 970ms/step - loss: -0.9361 - angular_loss: -0.9361 - mean_squared_error: 9326.9209 - val_loss: -0.9554 - val_angular_loss: -0.9558 - val_mean_squared_error: 6828.3467
# Epoch 45/100
# 186/186 [==============================] - 184s 988ms/step - loss: -0.9300 - angular_loss: -0.9299 - mean_squared_error: 8358.7295 - val_loss: -0.9540 - val_angular_loss: -0.9541 - val_mean_squared_error: 7232.6118
# Epoch 46/100
# 186/186 [==============================] - 186s 1s/step - loss: -0.9338 - angular_loss: -0.9339 - mean_squared_error: 8925.8467 - val_loss: -0.9670 - val_angular_loss: -0.9673 - val_mean_squared_error: 7446.7959
# Epoch 47/100
# 186/186 [==============================] - 186s 999ms/step - loss: -0.9327 - angular_loss: -0.9328 - mean_squared_error: 9437.2256 - val_loss: -0.9491 - val_angular_loss: -0.9496 - val_mean_squared_error: 7576.0181

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: -0.9676918983459473
# Test accuracy: -0.9657665491104126

# %%
from deepcompton.vizualisation import plot_backprojected,plot_source_pos
i=10

actual = np.radians(np.linspace(0,360, 180))
expected = np.arange(0,90,2)
r_g, theta_g = np.meshgrid(expected, actual)
ax = plot_backprojected(theta_g, r_g, x_test[i].reshape(180,45))
ax = plot_source_pos(y_test[i,0], np.radians(y_test[i,1]), ax=ax)
pred = model(tf.reshape(x_test[i],[1,180,45,1]))
print(pred.numpy())
print(y_test[i])
ax = plot_source_pos(pred[0,0], np.radians(pred[0,1]), ax=ax)
ax = plot_source_pos(pred[0,0], np.radians(pred[0,1]), ax=ax)
# Out:
# /home/aschulz/Documents/python/astroinfo2021/compton-hackathon/DeepIntegralCompton/deepcompton/vizualisation.py:63: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(tt)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [[ -0.99835765 129.67554   ]]
# [ 2. 72.]

# %%
pred = model(x_test).numpy()
from deepcompton.utils import angular_separation
# compute angular separation
y_real_rad = y_test * np.pi / 180.
y_pred_rad = pred * np.pi / 180.

angular_seps=angular_separation(y_real_rad[:,0],y_real_rad[:,1],
                               y_pred_rad[:,0],y_pred_rad[:,1]) * 180. / np.pi
angular_seps = np.array(angular_seps)
plt.figure()
plt.hist(angular_seps, bins=100)
print("Mean angular separation : {}".format(np.mean(angular_seps)))
plt.title("Angular separation after 26 epochs with lr=1e-4 'Angular Loss'")
plt.xlabel("Angular separation (deg)")
# Out:
# Mean angular separation : 14.113050136570196
# Text(0.5, 0, 'Angular separation (deg)')

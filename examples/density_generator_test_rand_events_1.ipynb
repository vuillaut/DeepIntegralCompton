# %%
import deepcompton
import os
import numpy as np
import matplotlib.pyplot as plt
print(os.getcwd())

data_dir = "../save_Compton"
if not os.path.exists(data_dir):
    print("Could not find data directory {}".format(data_dir))
# Out:
# /home/aschulz/Documents/python/astroinfo2021/compton-hackathon/DeepIntegralCompton/examples

# %%
# instrument caracteristics
z_isgri = 0.
z_picsit = -8.68

# %%
# first we need to create the dataset used for training and testing
from deepcompton.cones import make_cone_density
def make_dataset(datadir, max_n = 1000):
    y,x=[],[]
    for f in os.listdir(datadir):
        _,theta,_,phi=f.replace(".npy","").split("_")
        data = make_cone_density(theta, phi, z_isgri, z_picsit, datadir=datadir, progress=False)
        if data is not None:
            y.append([float(theta),float(phi)])
            x.append(data.reshape(180,45,1))
        if len(y)==max_n:
            break
        print(len(y))
    return np.array(x),np.array(y)
# pickled data
pkl_filename = "../cone_density_data_full_rand.pkl"
if os.path.exists(pkl_filename):
    import pickle as pkl
    fdata=pkl.load(open(pkl_filename,"rb"))
    x=[e[1] for e in fdata]
    y=[e[0] for e in fdata]
    def clean_pkl_data(x,y):
        a,b=[],[]
        for i in range(len(x)):
            if x[i] is not None:
                a.append(x[i].reshape(180,45,1))
                b.append(np.array([float(y[i][0]),float(y[i][1])]))
        return np.array(a),np.array(b)
    x,y = clean_pkl_data(x,y)
    
else:
    x,y = make_dataset(data_dir)
    pkl.dump((x,y),open(pkl_filename,"wb"))
print(x.shape, y.shape)
y *= np.pi / 180.
# Out:
# (65617, 180, 45, 1) (65617, 2)

# %%
# plot the distribution of the data
plt.figure()
plt.hist(x[0].flatten(),bins=100)
plt.show()

# %%
# normalize the data
from sklearn.preprocessing import scale
flat_x=[]
for i in range(x.shape[0]):
    flat_x.append(x[i].flatten())
flat_x=np.array(flat_x)

flat_x = scale(flat_x)

new_x = [flat_x[i].reshape(180,45,1) for i in range(flat_x.shape[0])]
new_x = np.array(new_x)
plt.figure()
plt.hist(new_x[0].flatten(),bins=100)
plt.show()

# %%
#from deepcompton.vizualisation import plot_backprojected
#plot_backprojected(y[0,0],y[0,1], x[0])

# %%
# creating the train and test data
from sklearn.model_selection import train_test_split
import tensorflow as tf
x_train,x_test, y_train,y_test = train_test_split(new_x, y, shuffle=True)

y_train,y_test = np.array(y_train), np.array(y_test)
x_train,x_test = np.array(x_train), np.array(x_test)
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)

# convert to tensorflow tensors
y_train = tf.convert_to_tensor(y_train)
x_train = tf.convert_to_tensor(x_train)
#y_test= tf.convert_to_tensor(y_test)
#x_test= tf.convert_to_tensor(x_test)
print("Train data : {} {}".format(x_train.shape, y_train.shape))
print("Test data  : {} {}".format(x_test.shape, y_test.shape))
# Out:
# 2021-12-07 21:51:31.810241: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-12-07 21:51:31.810316: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# (525, 180, 45, 1) (525, 2) (176, 180, 45, 1) (176, 2)
# Train data : (525, 180, 45, 1) (525, 2)
# Test data  : (176, 180, 45, 1) (176, 2)
# 2021-12-07 21:51:40.427991: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-12-07 21:51:40.428110: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-07 21:51:40.428194: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (mademu): /proc/driver/nvidia/version does not exist
# 2021-12-07 21:51:40.431474: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# definition of a first convolutional model
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, Dense, Flatten
def get_model():
    model = tf.keras.Sequential()
    model.add(Conv2D(32,3,input_shape=(180,45,1), activation="elu"))
    model.add(BatchNormalization())
    #model.add(Conv2D(64,3, activation="elu"))
    #model.add(BatchNormalization())
    model.add(Flatten())
    model.add(Dense(512,activation="elu"))
    model.add(BatchNormalization())
    #model.add(Dense(128,activation="relu"))
    #model.add(BatchNormalization())
    model.add(Dense(2, activation="elu"))
    return model

# %%
from deepcompton.utils import angular_separation
def angular_loss(y_true, y_pred):
    # convert to rad
    return -1. * (tf.math.sin(y_true[-1][0])*tf.math.sin(y_pred[-1][0])*
                  tf.math.cos(y_true[-1][1]-y_pred[-1][1])+
                  tf.math.cos(y_pred[-1][0])*tf.math.cos(y_true[-1][0]))

# %%
# create the model
model = get_model()
# Out:
# 2021-12-07 21:53:13.532036: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 501612544 exceeds 10% of free system memory.
# 2021-12-07 21:53:14.224220: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 501612544 exceeds 10% of free system memory.
# 2021-12-07 21:53:14.325756: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 501612544 exceeds 10% of free system memory.

# %%
epochs = 100
batch_size = 12

callbacks = [
    #keras.callbacks.ModelCheckpoint("save_at_{epoch}.h5"),
    tf.keras.callbacks.TensorBoard('./logs/density_cnn_1_aloss_1layer_rand'),
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10),
]



model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-2),
    loss=angular_loss,
    metrics=[angular_loss,"mean_squared_error"],
    #loss=angular_loss,
    #metrics=[angular_loss],
)

# %%
model.fit(
    x_train, y_train, 
    #steps_per_epoch=epochs,
    batch_size=batch_size, 
    epochs=epochs, 
    callbacks=callbacks, 
    validation_split = 0.2,
)
# Out:
# Epoch 1/100
# 186/186 [==============================] - 116s 605ms/step - loss: -0.7211 - angular_loss: -0.7214 - mean_squared_error: 21121.0605 - val_loss: -0.7782 - val_angular_loss: -0.7806 - val_mean_squared_error: 19740.3730
# Epoch 2/100
# 186/186 [==============================] - 100s 538ms/step - loss: -0.8166 - angular_loss: -0.8161 - mean_squared_error: 19183.7793 - val_loss: -0.8165 - val_angular_loss: -0.8183 - val_mean_squared_error: 17694.0332
# Epoch 3/100
# 186/186 [==============================] - 99s 535ms/step - loss: -0.8493 - angular_loss: -0.8492 - mean_squared_error: 18177.2559 - val_loss: -0.8194 - val_angular_loss: -0.8211 - val_mean_squared_error: 17382.4570
# Epoch 4/100
# 186/186 [==============================] - 100s 535ms/step - loss: -0.8382 - angular_loss: -0.8385 - mean_squared_error: 17354.1641 - val_loss: -0.8216 - val_angular_loss: -0.8235 - val_mean_squared_error: 16991.0918
# Epoch 5/100
# 186/186 [==============================] - 100s 537ms/step - loss: -0.8544 - angular_loss: -0.8546 - mean_squared_error: 16923.0430 - val_loss: -0.8623 - val_angular_loss: -0.8635 - val_mean_squared_error: 15996.3008
# Epoch 6/100
# 186/186 [==============================] - 100s 540ms/step - loss: -0.8560 - angular_loss: -0.8560 - mean_squared_error: 15323.2266 - val_loss: -0.7958 - val_angular_loss: -0.7953 - val_mean_squared_error: 12765.7539
# Epoch 7/100
# 186/186 [==============================] - 101s 542ms/step - loss: -0.8525 - angular_loss: -0.8527 - mean_squared_error: 13288.2051 - val_loss: -0.7405 - val_angular_loss: -0.7402 - val_mean_squared_error: 11916.3340
# Epoch 8/100
# 186/186 [==============================] - 101s 540ms/step - loss: -0.8796 - angular_loss: -0.8797 - mean_squared_error: 11979.4951 - val_loss: -0.9111 - val_angular_loss: -0.9120 - val_mean_squared_error: 10064.7236
# Epoch 9/100
# 186/186 [==============================] - 99s 533ms/step - loss: -0.8562 - angular_loss: -0.8564 - mean_squared_error: 11059.2012 - val_loss: -0.8848 - val_angular_loss: -0.8860 - val_mean_squared_error: 10966.6797
# Epoch 10/100
# 186/186 [==============================] - 100s 536ms/step - loss: -0.8883 - angular_loss: -0.8883 - mean_squared_error: 11124.1152 - val_loss: -0.8740 - val_angular_loss: -0.8747 - val_mean_squared_error: 10794.7383
# Epoch 11/100
# 186/186 [==============================] - 100s 536ms/step - loss: -0.8780 - angular_loss: -0.8781 - mean_squared_error: 11050.6602 - val_loss: -0.9321 - val_angular_loss: -0.9324 - val_mean_squared_error: 10164.4678
# Epoch 12/100
# 186/186 [==============================] - 100s 539ms/step - loss: -0.8801 - angular_loss: -0.8794 - mean_squared_error: 9056.8369 - val_loss: -0.9242 - val_angular_loss: -0.9247 - val_mean_squared_error: 17513.5059
# Epoch 13/100
# 186/186 [==============================] - 100s 539ms/step - loss: -0.8685 - angular_loss: -0.8686 - mean_squared_error: 9450.2969 - val_loss: -0.9116 - val_angular_loss: -0.9125 - val_mean_squared_error: 9302.0752
# Epoch 14/100
# 186/186 [==============================] - 103s 555ms/step - loss: -0.8829 - angular_loss: -0.8827 - mean_squared_error: 10050.7871 - val_loss: -0.9371 - val_angular_loss: -0.9378 - val_mean_squared_error: 8724.9219
# Epoch 15/100
# 186/186 [==============================] - 101s 545ms/step - loss: -0.8972 - angular_loss: -0.8973 - mean_squared_error: 10248.3682 - val_loss: -0.9164 - val_angular_loss: -0.9167 - val_mean_squared_error: 10495.2637
# Epoch 16/100
# 186/186 [==============================] - 100s 537ms/step - loss: -0.9141 - angular_loss: -0.9143 - mean_squared_error: 10258.5352 - val_loss: -0.9427 - val_angular_loss: -0.9432 - val_mean_squared_error: 9457.4385
# Epoch 17/100
# 186/186 [==============================] - 100s 535ms/step - loss: -0.8784 - angular_loss: -0.8785 - mean_squared_error: 9668.9121 - val_loss: -0.7713 - val_angular_loss: -0.7735 - val_mean_squared_error: 198894.2188
# Epoch 18/100
# 186/186 [==============================] - 100s 537ms/step - loss: -0.8975 - angular_loss: -0.8977 - mean_squared_error: 11042.4668 - val_loss: -0.8968 - val_angular_loss: -0.8976 - val_mean_squared_error: 220459.5156
# Epoch 19/100
# 186/186 [==============================] - 100s 536ms/step - loss: -0.8973 - angular_loss: -0.8973 - mean_squared_error: 11082.4082 - val_loss: -0.8673 - val_angular_loss: -0.8684 - val_mean_squared_error: 10476.5088
# Epoch 20/100
# 186/186 [==============================] - 100s 537ms/step - loss: -0.8859 - angular_loss: -0.8861 - mean_squared_error: 10794.1816 - val_loss: -0.8890 - val_angular_loss: -0.8901 - val_mean_squared_error: 10123.2637
# Epoch 21/100
# 186/186 [==============================] - 100s 539ms/step - loss: -0.9290 - angular_loss: -0.9290 - mean_squared_error: 10473.8965 - val_loss: -0.9405 - val_angular_loss: -0.9411 - val_mean_squared_error: 9576.5947
# Epoch 22/100
# 186/186 [==============================] - 101s 545ms/step - loss: -0.9054 - angular_loss: -0.9046 - mean_squared_error: 9586.6055 - val_loss: -0.9123 - val_angular_loss: -0.9132 - val_mean_squared_error: 9238.0918
# Epoch 23/100
# 186/186 [==============================] - 103s 554ms/step - loss: -0.9246 - angular_loss: -0.9246 - mean_squared_error: 9771.6553 - val_loss: -0.9574 - val_angular_loss: -0.9577 - val_mean_squared_error: 8959.0488
# Epoch 24/100
# 186/186 [==============================] - 105s 564ms/step - loss: -0.9192 - angular_loss: -0.9193 - mean_squared_error: 9486.4219 - val_loss: -0.9502 - val_angular_loss: -0.9504 - val_mean_squared_error: 8688.3535
# Epoch 25/100
# 186/186 [==============================] - 109s 585ms/step - loss: -0.9141 - angular_loss: -0.9142 - mean_squared_error: 8333.1475 - val_loss: -0.9533 - val_angular_loss: -0.9536 - val_mean_squared_error: 7974.1782
# Epoch 26/100
# 186/186 [==============================] - 105s 563ms/step - loss: -0.9080 - angular_loss: -0.9072 - mean_squared_error: 8806.4375 - val_loss: -0.9368 - val_angular_loss: -0.9372 - val_mean_squared_error: 8894.3398
# Epoch 27/100
# 186/186 [==============================] - 101s 542ms/step - loss: -0.9146 - angular_loss: -0.9148 - mean_squared_error: 9235.0195 - val_loss: -0.9678 - val_angular_loss: -0.9679 - val_mean_squared_error: 8449.1631
# Epoch 28/100
# 186/186 [==============================] - 101s 543ms/step - loss: -0.9272 - angular_loss: -0.9267 - mean_squared_error: 9354.2793 - val_loss: -0.9575 - val_angular_loss: -0.9577 - val_mean_squared_error: 8289.7109
# Epoch 29/100
# 186/186 [==============================] - 104s 561ms/step - loss: -0.9290 - angular_loss: -0.9290 - mean_squared_error: 8803.5439 - val_loss: -0.9472 - val_angular_loss: -0.9470 - val_mean_squared_error: 8341.7197
# Epoch 30/100
# 186/186 [==============================] - 103s 556ms/step - loss: -0.9277 - angular_loss: -0.9276 - mean_squared_error: 8897.7471 - val_loss: -0.9743 - val_angular_loss: -0.9744 - val_mean_squared_error: 8658.5811
# Epoch 31/100
# 186/186 [==============================] - 104s 557ms/step - loss: -0.9098 - angular_loss: -0.9099 - mean_squared_error: 9376.4736 - val_loss: -0.9719 - val_angular_loss: -0.9721 - val_mean_squared_error: 10150.3252
# Epoch 32/100
# 186/186 [==============================] - 102s 550ms/step - loss: -0.9241 - angular_loss: -0.9242 - mean_squared_error: 9432.2939 - val_loss: -0.9624 - val_angular_loss: -0.9622 - val_mean_squared_error: 11623.5674
# Epoch 33/100
# 186/186 [==============================] - 104s 558ms/step - loss: -0.9180 - angular_loss: -0.9179 - mean_squared_error: 9065.4053 - val_loss: -0.9728 - val_angular_loss: -0.9727 - val_mean_squared_error: 49372.7656
# Epoch 34/100
# 186/186 [==============================] - 105s 563ms/step - loss: -0.9103 - angular_loss: -0.9104 - mean_squared_error: 9223.0430 - val_loss: -0.9519 - val_angular_loss: -0.9522 - val_mean_squared_error: 324614.9062
# Epoch 35/100
# 186/186 [==============================] - 106s 568ms/step - loss: -0.9256 - angular_loss: -0.9257 - mean_squared_error: 8789.6670 - val_loss: -0.9689 - val_angular_loss: -0.9689 - val_mean_squared_error: 114182.4531
# Epoch 36/100
# 186/186 [==============================] - 106s 568ms/step - loss: -0.9362 - angular_loss: -0.9362 - mean_squared_error: 8739.9346 - val_loss: -0.9702 - val_angular_loss: -0.9703 - val_mean_squared_error: 118404.6797
# Epoch 37/100
# 186/186 [==============================] - 106s 571ms/step - loss: -0.9268 - angular_loss: -0.9267 - mean_squared_error: 8575.2891 - val_loss: -0.9714 - val_angular_loss: -0.9717 - val_mean_squared_error: 36574.9102
# Epoch 38/100
# 186/186 [==============================] - 107s 573ms/step - loss: -0.9288 - angular_loss: -0.9289 - mean_squared_error: 9007.3086 - val_loss: -0.9741 - val_angular_loss: -0.9740 - val_mean_squared_error: 17278.3125
# Epoch 39/100
# 186/186 [==============================] - 107s 577ms/step - loss: -0.9358 - angular_loss: -0.9356 - mean_squared_error: 8863.9180 - val_loss: -0.9665 - val_angular_loss: -0.9668 - val_mean_squared_error: 162746.8125
# Epoch 40/100
# 186/186 [==============================] - 108s 580ms/step - loss: -0.9350 - angular_loss: -0.9350 - mean_squared_error: 8566.4326 - val_loss: -0.9767 - val_angular_loss: -0.9768 - val_mean_squared_error: 419212.3438
# Epoch 41/100
# 186/186 [==============================] - 108s 579ms/step - loss: -0.9207 - angular_loss: -0.9207 - mean_squared_error: 8497.4209 - val_loss: -0.9684 - val_angular_loss: -0.9686 - val_mean_squared_error: 496545.0312
# Epoch 42/100
# 186/186 [==============================] - 108s 582ms/step - loss: -0.9252 - angular_loss: -0.9253 - mean_squared_error: 8126.6758 - val_loss: -0.9671 - val_angular_loss: -0.9674 - val_mean_squared_error: 8234.2490
# Epoch 43/100
# 186/186 [==============================] - 108s 581ms/step - loss: -0.9180 - angular_loss: -0.9181 - mean_squared_error: 8971.1318 - val_loss: -0.9705 - val_angular_loss: -0.9708 - val_mean_squared_error: 8789.4551
# Epoch 44/100
# 186/186 [==============================] - 109s 588ms/step - loss: -0.9161 - angular_loss: -0.9160 - mean_squared_error: 9348.3223 - val_loss: -0.9729 - val_angular_loss: -0.9731 - val_mean_squared_error: 8559.7373
# Epoch 45/100
# 186/186 [==============================] - 109s 584ms/step - loss: -0.9215 - angular_loss: -0.9215 - mean_squared_error: 9225.3535 - val_loss: -0.9725 - val_angular_loss: -0.9727 - val_mean_squared_error: 8692.7676
# Epoch 46/100
# 186/186 [==============================] - 109s 588ms/step - loss: -0.9319 - angular_loss: -0.9319 - mean_squared_error: 9335.2549 - val_loss: -0.9746 - val_angular_loss: -0.9748 - val_mean_squared_error: 8856.9600
# Epoch 47/100
# 186/186 [==============================] - 109s 586ms/step - loss: -0.9130 - angular_loss: -0.9132 - mean_squared_error: 8867.4863 - val_loss: -0.9754 - val_angular_loss: -0.9755 - val_mean_squared_error: 8844.5938
# Epoch 48/100
# 186/186 [==============================] - 110s 592ms/step - loss: -0.9287 - angular_loss: -0.9281 - mean_squared_error: 8760.4365 - val_loss: -0.9612 - val_angular_loss: -0.9616 - val_mean_squared_error: 1709880.6250
# Epoch 49/100
# 186/186 [==============================] - 109s 585ms/step - loss: -0.9403 - angular_loss: -0.9403 - mean_squared_error: 8852.4365 - val_loss: -0.9629 - val_angular_loss: -0.9629 - val_mean_squared_error: 8344.2881
# Epoch 50/100
# 186/186 [==============================] - 109s 587ms/step - loss: -0.9225 - angular_loss: -0.9226 - mean_squared_error: 8665.4062 - val_loss: -0.9614 - val_angular_loss: -0.9616 - val_mean_squared_error: 8875.3555

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: -0.9566128253936768
# Test accuracy: -0.9567391872406006

# %%
from deepcompton.vizualisation import plot_backprojected,plot_source_pos
i=10

actual = np.radians(np.linspace(0,360, 180))
expected = np.arange(0,90,2)
r_g, theta_g = np.meshgrid(expected, actual)
ax = plot_backprojected(theta_g, r_g, x_test[i].reshape(180,45))
ax = plot_source_pos(y_test[i,0], np.radians(y_test[i,1]), ax=ax)
pred = model(tf.reshape(x_test[i],[1,180,45,1]))
print(pred.numpy())
print(y_test[i])
ax = plot_source_pos(pred[0,0], np.radians(pred[0,1]), ax=ax)
ax = plot_source_pos(pred[0,0], np.radians(pred[0,1]), ax=ax)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [[  9.366678 221.46645 ]]
# [ 20. 228.]

# %%
pred = model(x_test).numpy()
from deepcompton.utils import angular_separation
# compute angular separation
y_real_rad = y_test * np.pi / 180.
y_pred_rad = pred * np.pi / 180.

angular_seps=angular_separation(y_real_rad[:,0],y_real_rad[:,1],
                               y_pred_rad[:,0],y_pred_rad[:,1]) * 180. / np.pi
angular_seps = np.array(angular_seps)
plt.figure()
plt.hist(angular_seps, bins=100)
print("Mean angular separation : {}".format(np.mean(angular_seps)))
plt.title("Angular separation after 26 epochs with lr=1e-4 'Angular Loss'")
plt.xlabel("Angular separation (deg)")
# Out:
# Mean angular separation : 14.40634962544638
# Text(0.5, 0, 'Angular separation (deg)')

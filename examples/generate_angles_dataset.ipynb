# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import matplotlib.pyplot as plt
from astropy.table import Table
from tqdm import tqdm
from astropy.io.misc.hdf5 import write_table_hdf5

from deepcompton.utils import load_data
from deepcompton.cones import make_cone, AnglesDataset

# %%
# Path to the source directory with  all the `.npy` files
src_dir = '../../Data/'

# %%
angle_ds = AnglesDataset()

# %%
# angle_ds.generate(src_dir)

# %%
# angle_ds.save('dataset_angles.pickle')

# %%
angle_ds.load('dataset_angles.pickle');
tab = angle_ds.tab

# %%
tab[:5]
# Out:
# <Table length=5>
# src_theta src_phi ...                                   phi                                                                      cotheta
#   int64    int64  ...                                  object                                                                     object
# --------- ------- ... ----------------------------------------------------------------------- ------------------------------------------------------------------------------
#        68     196 ... [3.41773171 1.04359968 4.4806442  ... 3.33325827 5.31102948 1.26710319] [ 1.52552928  0.36970468  0.90527268 ... -0.26883503 -0.76158521
#  -0.1813451 ]
#        10      44 ... [4.58417631 1.03037683 1.90730797 ... 3.74440059 3.15048272 2.94838117]        [0.7001196  4.75381282 3.68256264 ... 0.30083399 0.39934565 1.48185691]
#        72     240 ... [4.49021463 4.75041412 1.52939987 ... 4.45559652 4.52540971 5.49778714] [ 1.99658029  1.12697802 -0.04427044 ...  2.71288062  0.30825995
#   0.06977709]
#        34     148 ... [0.81719337 1.76732156 1.87465014 ... 3.15252972 4.16809234 1.11145904] [-0.35151871 -0.03339247  1.02225712 ...  1.12925033  0.38255903
#   0.28448687]
#        10     272 ... [2.99860627 3.466253   6.06763011 ... 0.01938815 5.39314286 4.07478777]        [0.79436355 2.30594881 0.82604957 ... 1.03126271 0.21529941 2.03254306]

# %%
lengths = [len(t) for t in tab['theta']]

# %%
plt.hist(lengths, bins=100);

# %%
from deepcompton.vizualisation import plot_source_pos

# %%
ax = plot_source_pos(np.deg2rad(tab['src_theta']), np.deg2rad(tab['src_phi']), figsize=(10,8), s=3)
ax.set_title('Positions of simulated sources in the sky')
# Out:
# Text(0.5, 1.0, 'Positions of simulated sources in the sky')
